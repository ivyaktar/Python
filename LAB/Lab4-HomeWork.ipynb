# %%
#Task1

class Student:
  def __init__(self,name,cgpa,creds = 9,dep = 'CSE'):
    self.gpa = cgpa
    self.dep = dep
    self.name = name
    self.creds = creds
    self.merit = False
    self.need = False
  def checkScholarshipEligibility(self):
    if self.gpa >= 3.5 and self.creds > 10:
      if self.gpa >= 3.7:
        print(f'{self.name} is eligible for Merit-based scholarship.')
        self.merit = True
      elif 3.7 > self.gpa >= 3.5:
        print(f'{self.name} is eligible for Need-based scholarship.')
        self.need = True
      else:
        print(f'{self.name} is not eligible for scholarship.')

    else:
      print(f'{self.name} is not eligible for scholarship.')

  def showDetails(self):
    print(f'Name: {self.name}')
    print(f'Department: {self.dep}')
    print(f'CGPA: {self.gpa}')
    print(f'Number of Credits: {self.creds}')
    if self.merit:
      print('Scholarship Status: Merit-based scholarship')
    elif self.need:
      print('Scholarship Status: Need-based scholarship')
    else:
      print('Scholarship Status: No scholarship')

#DriverCode
print('--------------------------')
std1 = Student("Alif", 3.99, 12)
print('--------------------------')
std1.checkScholarshipEligibility()
print('--------------------------')
std1.showDetails()
print('--------------------------')
std2 = Student("Mim", 3.4)
std3 = Student("Henry", 3.5, 15,"BBA")
print('--------------------------')
std2.checkScholarshipEligibility()
print('--------------------------')
std3.checkScholarshipEligibility()
print('--------------------------')
std2.showDetails()
print('--------------------------')
std3.showDetails()
print('--------------------------')
std4 = Student("Bob", 4.0, 6, "CSE")
print('--------------------------')
std4.checkScholarshipEligibility()
print('--------------------------')
std4.showDetails()
# Out:
# --------------------------
# --------------------------
# Alif is eligible for Merit-based scholarship.
# --------------------------
# Name: Alif
# Department: CSE
# CGPA: 3.99
# Number of Credits: 12
# Scholarship Status: Merit-based scholarship
# --------------------------
# --------------------------
# Mim is not eligible for scholarship.
# --------------------------
# Henry is eligible for Need-based scholarship.
# --------------------------
# Name: Mim
# Department: CSE
# CGPA: 3.4
# Number of Credits: 9
# Scholarship Status: No scholarship
# --------------------------
# Name: Henry
# Department: BBA
# CGPA: 3.5
# Number of Credits: 15
# Scholarship Status: Need-based scholarship
# --------------------------
# --------------------------
# Bob is not eligible for scholarship.
# --------------------------
# Name: Bob
# Department: CSE
# CGPA: 4.0
# Number of Credits: 6
# Scholarship Status: No scholarship

# %%
#Task2

class Foodie:
  def __init__(self,client):
    self.client = client
    self.dic1 = {}
    self.ts = 0
    self.item_list = []
  def order(self, *items):
    for i in items:
      list1 = i.split('-')
      item = list1[0]
      self.item_list += [item]
      quantity = list1[1]
      print(f'Ordered - {item}, quantity - {quantity}, price (per Unit) - {menu[item]}.')
      tp = menu[item]*int(quantity)
      print(f'Total price - {menu[item]*int(quantity)}')
      self.ts += tp
  def show_orders(self):
    return (f'{self.client} has {len(self.item_list)} item(s) in the cart.\nItems: {self.item_list}\nTotal spent: {self.ts}')
  def pay_tips(self,amount = 0):
    if amount == 0:
      print(f'No tips to the waiter')
    else:
      print(f'Gives {amount}/- tips to the waiter.')
      self.ts += amount

#DriveCode
menu = {'Chicken Lollipop':15,'Beef Nugget':20,'Americano':180,'Red Velvet':150,'Prawn Tempura':80,'Saute Veg':200}

f1 = Foodie('Frodo')
print(f1.show_orders())
print('1----------------------')
f1.order('Chicken Lollipop-3','Beef Nugget-6','Americano-1')
print('2----------------------')
print(f1.show_orders())
print('3----------------------')
f1.order('Red Velvet-1')
print('4----------------------')
f1.pay_tips(20)
print('5----------------------')
print(f1.show_orders())
f2 = Foodie('Bilbo')
print('6----------------------')
f2.order('Prawn Tempura-6','Saute Veg-1')
print('7----------------------')
f2.pay_tips()
print('8----------------------')
print(f2.show_orders())
# Out:
# Frodo has 0 item(s) in the cart.
# Items: []
# Total spent: 0
# 1----------------------
# Ordered - Chicken Lollipop, quantity - 3, pritce (per Unit) - 15.
# Total price - 45
# Ordered - Beef Nugget, quantity - 6, pritce (per Unit) - 20.
# Total price - 120
# Ordered - Americano, quantity - 1, pritce (per Unit) - 180.
# Total price - 180
# 2----------------------
# Frodo has 3 item(s) in the cart.
# Items: ['Chicken Lollipop', 'Beef Nugget', 'Americano']
# Total spent: 345
# 3----------------------
# Ordered - Red Velvet, quantity - 1, pritce (per Unit) - 150.
# Total price - 150
# 4----------------------
# Gives 20/- tips to the waiter.
# 5----------------------
# Frodo has 4 item(s) in the cart.
# Items: ['Chicken Lollipop', 'Beef Nugget', 'Americano', 'Red Velvet']
# Total spent: 515
# 6----------------------
# Ordered - Prawn Tempura, quantity - 6, pritce (per Unit) - 80.
# Total price - 480
# Ordered - Saute Veg, quantity - 1, pritce (per Unit) - 200.
# Total price - 200
# 7----------------------
# No tips to the waiter
# 8----------------------
# Bilbo has 2 item(s) in the cart.
# Items: ['Prawn Tempura', 'Saute Veg']
# Total spent: 680

# %%
#Task3

class Department:
  def __init__(self,dep = 'ChE',sec = 5):
    self.dep = dep
    self.sec = sec
    self.total = 0
    self.avg = 0
    print(f'The {self.dep} Department has {self.sec} sections.')
  def add_students(self,*students):
    self.students = students
    if len(students) != self.sec:
      print(f"The {self.dep} Department doesn't have {len(students)} sections.")
    else:
      for i in students:
        self.total += i
      self.avg = self.total / self.sec
      print(f'The {self.dep} Department has an average of {round(self.avg,2)} students in each section.')
  def merge_Department(self,*deps):
    out = ''
    self.ts = self.avg * self.sec
    for i in deps:
      out += f'{i.dep} Department is merged to {self.dep}.\n'
      self.ts += i.sec * i.avg
    self.avg = self.ts/self.sec
    out += f'Now the {self.dep} has and average of {self.avg} students in each section.'
    return out

#DriverCode
d1 = Department()
print('1-----------------------------')
d2 = Department('MME Department')
print('2-----------------------------')
d3 = Department('NCE Department', 8)
print('3-----------------------------')
d1.add_students(12, 23, 12, 34, 21)
print('4-----------------------------')
d2.add_students(40, 30, 21)
print('5-----------------------------')
d3.add_students(12, 34, 41, 17, 30, 22, 32, 51)
print('6-----------------------------')
mega = Department('Engineering Department', 10)
print('7-----------------------------')
mega.add_students(21,30,40,36,10,32,27,51,45,15)
print('8-----------------------------')
print(mega.merge_Department(d1, d2))
print('9-----------------------------')
print(mega.merge_Department(d3))
# Out:
# The ChE Department has 5 sections.
# 1-----------------------------
# The MME Department Department has 5 sections.
# 2-----------------------------
# The NCE Department Department has 8 sections.
# 3-----------------------------
# The ChE Department has an average of 20.4 students in each section.
# 4-----------------------------
# The MME Department Department doesn't have 3 sections.
# 5-----------------------------
# The NCE Department Department has an average of 29.88 students in each section.
# 6-----------------------------
# The Engineering Department Department has 10 sections.
# 7-----------------------------
# The Engineering Department Department has an average of 30.7 students in each section.
# 8-----------------------------
# ChE Department is merged to Engineering Department.
# MME Department Department is merged to Engineering Department.
# Now the Engineering Department has and average of 40.9 students in each section.
# 9-----------------------------
# NCE Department Department is merged to Engineering Department.
# Now the Engineering Department has and average of 64.8 students in each section.

# %%
#Task4

class Shopidify():
  def __init__(self, name = None):

    self.name = name
    if name == None:
      print(f'Welcome to Shopidify')
    else:
      print(f'Welcome {name} to Shopidify')
    self.dic1 = {}

  def add_to_cart(self,*items):

    if type(items[0]) == type([]):
      list1 = items[0]
    else:
      list1 = list(items)

    for i in range(0,len(list1),2):
      if len(list1) == 1:
        if list1[i] not in self.dic1:
          self.dic1[list1[i]] = 1
        else:
          self.dic1[list1[i]] += 1
      else:
        self.dic1[list1[i]] = list1[i+1]

  def display_cart(self):
    print(f'Items in the cart for {self.name}')
    for k,v in self.dic1.items():
      print(f'-{k}: {v}x')

  def checkout(self):
    print(f'Checkout completed for {self.name}')

  def display_history(self):
    print(f'Purchase history for {self.name}')
    print(f'Transaction 1:')
    for k,v in self.dic1.items():
      print(f'-{k}: {v}x')

#DriverCode
guest_account = Shopidify()
print("1xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account = Shopidify("John")
print("2xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.add_to_cart("Air Jordan", 2)
guest_account.add_to_cart("Luffy Action Figure")
guest_account.display_cart()
print("3xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.add_to_cart(["Chocolate Chip Cookies", 3,"Goku Action Figure",2,"Dumbbells-5kg",2])
john_account.display_cart()
print("4xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.add_to_cart("Air Jordan")
guest_account.display_cart()
print("5xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.checkout()
print("6xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
guest_account.display_history()
print("7xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.checkout()
print("8xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
john_account.display_history()
print("9xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
# Out:
# Welcome to Shopidify
# 1xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Welcome John to Shopidify
# 2xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Items in the cart for None
# -Air Jordan: 2x
# -Luffy Action Figure: 1x
# 3xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Items in the cart for John
# -Chocolate Chip Cookies: 3x
# -Goku Action Figure: 2x
# -Dumbbells-5kg: 2x
# 4xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Items in the cart for None
# -Air Jordan: 3x
# -Luffy Action Figure: 1x
# 5xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Checkout completed for None
# 6xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Purchase history for None
# Transaction 1:
# -Air Jordan: 3x
# -Luffy Action Figure: 1x
# 7xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Checkout completed for John
# 8xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Purchase history for John
# Transaction 1:
# -Chocolate Chip Cookies: 3x
# -Goku Action Figure: 2x
# -Dumbbells-5kg: 2x
# 9xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx

# %%
#Task5

class Author:
  def __init__(self,name = None):
    self.name = name
    self.num = 0
    self.dic1 = {}
  def addBook(self,bn,genre):
    if self.name == None:
      print(f'A book can not be added without author name')
    else:
      self.num += 1
      self.dic1[genre] = bn
  def setName(self,name2):
    self.name = name2
  def printDetail(self):
    print(f'Number of Book(s): {self.num}')
    print(f'Author Name: {self.name}')
    for k,v in self.dic1.items():
      print(f'{k}: {v}')

#DriverCode
a1 = Author()
print("=================================")
a1.addBook("Ice", "Science Fiction")
print("=================================")
a1.setName("Anna Kavan")
a1.addBook("Ice", "Science Fiction")
a1.printDetail()
print("=================================")
a2 = Author("Humayun Ahmed")
a2.addBook("Onnobhubon", "Science Fiction")
a2.addBook("Megher Upor Bari", "Horror")
print("=================================")
a2.printDetail()
a2.addBook("Ireena", "Science Fiction")
print("=================================")
a2.printDetail()
print("=================================")
# Out:
# =================================
# A book can not be added without author name
# =================================
# Number of Book(s): 1
# Author Name: Anna Kavan
# Science Fiction: Ice
# =================================
# =================================
# Number of Book(s): 2
# Author Name: Humayun Ahmed
# Science Fiction: Onnobhubon
# Horror: Megher Upor Bari
# =================================
# Number of Book(s): 3
# Author Name: Humayun Ahmed
# Science Fiction: Ireena
# Horror: Megher Upor Bari
# =================================
