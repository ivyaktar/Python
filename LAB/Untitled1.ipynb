# %%
Print(0%3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-bc1a084e92ce> in <cell line: 1>()
# ----> 1 Print(0%3)
#
# NameError: name 'Print' is not defined
